# %% [markdown]
# <a href="https://colab.research.google.com/github/DariAlves/samsung-ocean-jornada-python-032021/blob/main/samsung_ocean_jornada_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Olá, mundo!")
# Out:
# Olá, mundo!

# %%
saudacao = "Olá, mundo!"
print(saudacao)
# Out:
# Olá, mundo!

# %%
nome = 'Dari'
sobrenome = 'Alves'

print(nome)
print(sobrenome)
# Out:
# Dari
# Alves

# %%
numero = 5
print(numero)
# Out:
# 5

# %%
numero += 5

print(numero)
# Out:
# 10

# %%
print(numero + 10)
# Out:
# 20

# %%
'''
comentário
com
varias
linhas
''';

print('comentarios')
# Out:
# comentarios

# %%
numero = 5
numeroDecimal = 5.5
texto = 'Dari'
maiorIdade = True

print(numero, type(numero))
print(numeroDecimal, type(numeroDecimal))
print(texto, type(texto))
print(maiorIdade, type(maiorIdade))
# Out:
# 5 <class 'int'>
# 5.5 <class 'float'>
# Dari <class 'str'>
# True <class 'bool'>
