# %%
print("Olá, mundo!")
# Out:
# Olá, mundo!

# %%
saudacao = "Olá, mundo!"
print(saudacao)
# Out:
# Olá, mundo!

# %%
nome = 'Dari'
sobrenome = 'Alves'

print(nome)
print(sobrenome)
# Out:
# Dari
# Alves

# %%
numero = 5
print(numero)
# Out:
# 5

# %%
numero += 5

print(numero)
# Out:
# 10

# %%
print(numero + 10)
# Out:
# 20

# %%
'''
comentário
com
varias
linhas
''';

print('comentarios')
# Out:
# comentarios

# %%
numero = 5
numero_decimal = 5.5
texto = 'Dari'
maior_idade = True

print(numero, type(numero))
print(numero_decimal, type(numero_decimal))
print(texto, type(texto))
print(maior_idade, type(maior_idade))
# Out:
# 5 <class 'int'>
# 5.5 <class 'float'>
# Dari <class 'str'>
# True <class 'bool'>

# %%
soma = 2 + 3
subtracao = 5 - 3
divisao = 10 / 3 # retorna um float
multiplicacao = 8 * 5 
exponenciacao = 2 ** 3
quociente_divisao = 10 // 3
resto_divisao = 10 % 3

print(soma, subtracao, divisao, multiplicacao, exponenciacao, quociente_divisao, resto_divisao)
# Out:
# 5 2 3.3333333333333335 40 8 3 1

# %%
print("10/3 =",divisao, "10//3 =",quociente_divisao, "10%3 =",resto_divisao)
# Out:
# 10/3 = 3.3333333333333335 10//3 = 3 10%3 = 1

# %% [markdown]
# # Exercício 1 - "E os 10% do garçom?"
#
# - Defina uma variável para o valor de uma refeição que custou `R$ 42,54`;
# - Defina uma variável para o valor da taxa de serviço que é de `10%`;
# - Defina uma variável que calcula o valor total da conta e exiba-o no console (sem formatação, por enquanto, apenas o valor do resultado).

# %%
# Exercício 1 - 10% do garçom

valor_refeicao = float(input('Digite o valor da refeição: '))
valor_taxa = 10/100 * valor_refeicao
valor_total = valor_taxa + valor_refeicao

print(f"O valor total: R$ {valor_total:.2f}.")
# Out:
# Digite o valor da refeição: 42.54
# O valor total: R$ 46.79.

# %%
# Indentação e formatação dos blocos

if True:
  print('indentacao')

def exibir_numeros(numero):
  print(numero)
  print(numero * 5)
  print('dentro da funcao')

print('fora da funcao')

exibir_numeros(5)
# Out:
# indentacao
# fora da funcao
# 5
# 25
# dentro da funcao

# %% [markdown]
# # Exercício 2 - Input de Informações
# Objetivo: Receber dados do usuário, trabalhar com os valores e exibir para o usuário.
#
# Dificuldade: Principiante
#
# 1 - Crie um programa que receba do usuário seu nome, idade e gênero;
#
# 2 - Exiba na tela seguinte mensagem: "Olá, {nome}, você possui {idade} anos de idade e é do gênero {genero}.";
#
# 3 - Exiba também: "Já pensou no que você fará no seu aniversário de {idade + 1} anos?".
#
# Adicionando uma pimentinha extra: "Se o usuário digitar idade 1, exiba apenas "ano" em vez de "anos". """
